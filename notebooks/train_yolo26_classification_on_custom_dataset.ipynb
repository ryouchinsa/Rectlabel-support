# %% [markdown]
# <a href="https://colab.research.google.com/github/ryouchinsa/Rectlabel-support/blob/master/notebooks/train_yolo26_classification_on_custom_dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # How to Train a YOLO26 Classification Model with Custom Data
#
# We will show you how to train a YOLO26 classification model with your images and annotations and export to a Core ML model which can be used for auto labeling on RectLabel.

# %% [markdown]
# ### Use GPU
#
# Let's make sure that we have access to GPU. We can use `nvidia-smi` command to do that. In case of any problems navigate to `Runtime` -> `Change runtime type` -> `Hardware accelerator`, set it to `GPU`, and then click `Save`.

# %%
# !nvidia-smi
# Out:
# Sun Mar  8 00:38:05 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   45C    P8              9W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %% [markdown]
# ### Install YOLO26

# %%
# %pip install -q ultralytics
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 31.6 MB/s eta 0:00:00

# %% [markdown]
# ### Download training images and annotations
#
# Download training images and annotations. You can use these or replace them with your own data.

# %%
# !wget -q https://huggingface.co/datasets/rectlabel/datasets/resolve/main/converse_vans_classification.zip
# !unzip -q converse_vans_classification.zip

# %% [markdown]
# ### Fine-tune YOLO26 on custom dataset

# %%
# !yolo classify train data=converse_vans_classification model=yolo26n-cls.pt epochs=100
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolo26n-cls.pt to 'yolo26n-cls.pt': 100% ━━━━━━━━━━━━ 5.5MB 101.6MB/s 0.1s
# Ultralytics 8.4.21 🚀 Python-3.12.12 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# engine/trainer: agnostic_nms=False, amp=True, angle=1.0, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=converse_vans_classification, degrees=0.0, deterministic=True, device=None, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, end2end=None, epochs=100, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=224, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolo26n-cls.pt, momentum=0.937, mosaic=1.0, multi_scale=0.0, name=train, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=None, rect=False, resume=False, retina_masks=False, rle=1.0, save=True, save_conf=False, save_crop=False, save_dir=/content/runs/classify/train, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=classify, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# train: /content/converse_vans_classification/train... found 712 images in 2 classes ✅
# val: /content/converse_vans_classification/val... found 96 images in 2 classes ✅
# test: /content/converse_vans_classification/test... found 86 images in 2 classes ✅
# Overriding model.yaml nc=1000 with nc=2
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      6640  ultralytics.nn.modules.block.C3k2            [32, 64, 1, False, 0.25]
#   3                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#   4                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   5                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   6                  -1  1     87040  ultralytics.nn.modules.block.C3k2            [128, 128, 1, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    346112  ultralytics.nn.modules.block.C3k2            [256, 256, 1, True]
#   9                  -1  1    249728  ultralytics.nn.modules.block.C2PSA           [256, 256, 1]
#  10                  -1  1    332802  ultralytics.nn.modules.head.Classify         [256, 2]
# YOLO26n-cls summary: 86 layers, 1,533,666 parameters, 1,533,666 gradients, 3.3 GFLOPs
# Transferred 234/236 items from pretrained weights
# AMP: running Automatic Mixed Precision (AMP) checks...
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolo26n.pt to 'yolo26n.pt': 100% ━━━━━━━━━━━━ 5.3MB 93.1MB/s 0.1s
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 843.0±376.6 MB/s, size: 26.0 KB)
# train: Scanning /content/converse_vans_classification/train... 712 images, 0 corrupt: 100% ━━━━━━━━━━━━ 712/712 6.1Kit/s 0.1s
# train: New cache created: /content/converse_vans_classification/train.cache
# val: Fast image access ✅ (ping: 0.0±0.1 ms, read: 523.4±359.2 MB/s, size: 30.9 KB)
# val: Scanning /content/converse_vans_classification/val... 96 images, 0 corrupt: 100% ━━━━━━━━━━━━ 96/96 4.6Kit/s 0.0s
# val: New cache created: /content/converse_vans_classification/val.cache
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.001667, momentum=0.9) with parameter groups 39 weight(decay=0.0), 40 weight(decay=0.0005), 40 bias(decay=0.0)
# Image sizes 224 train, 224 val
# Using 2 dataloader workers
# Logging results to /content/runs/classify/train
# Starting training for 100 epochs...
#
#       Epoch    GPU_mem       loss  Instances       Size
# Downloading https://ultralytics.com/assets/Arial.ttf to '/root/.config/Ultralytics/Arial.ttf': 100% ━━━━━━━━━━━━ 755.1KB 21.4MB/s 0.0s
#       1/100     0.279G     0.5362          8        224: 100% ━━━━━━━━━━━━ 45/45 4.0it/s 11.3s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 5.2it/s 0.6s
#                    all      0.885          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       2/100     0.279G     0.3116          8        224: 100% ━━━━━━━━━━━━ 45/45 7.3it/s 6.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 22.9it/s 0.1s
#                    all      0.865          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       3/100     0.279G     0.3185          8        224: 100% ━━━━━━━━━━━━ 45/45 9.1it/s 4.9s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 21.4it/s 0.1s
#                    all      0.896          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       4/100     0.279G     0.2976          8        224: 100% ━━━━━━━━━━━━ 45/45 7.0it/s 6.4s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 23.4it/s 0.1s
#                    all      0.865          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       5/100     0.279G     0.2882          8        224: 100% ━━━━━━━━━━━━ 45/45 9.1it/s 4.9s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 24.0it/s 0.1s
#                    all      0.875          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       6/100     0.279G     0.2818          8        224: 100% ━━━━━━━━━━━━ 45/45 6.8it/s 6.6s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 33.1it/s 0.1s
#                    all      0.833          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       7/100     0.279G     0.3395          8        224: 100% ━━━━━━━━━━━━ 45/45 8.9it/s 5.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 31.9it/s 0.1s
#                    all      0.885          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       8/100     0.279G      0.283          8        224: 100% ━━━━━━━━━━━━ 45/45 6.9it/s 6.6s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 46.8it/s 0.1s
#                    all      0.823          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       9/100     0.279G     0.2525          8        224: 100% ━━━━━━━━━━━━ 45/45 8.7it/s 5.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 28.6it/s 0.1s
#                    all      0.927          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      10/100     0.279G     0.2346          8        224: 100% ━━━━━━━━━━━━ 45/45 7.2it/s 6.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 19.4it/s 0.2s
#                    all      0.927          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      11/100     0.279G     0.2381          8        224: 100% ━━━━━━━━━━━━ 45/45 8.6it/s 5.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 31.7it/s 0.1s
#                    all      0.865          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      12/100     0.279G     0.2514          8        224: 100% ━━━━━━━━━━━━ 45/45 7.1it/s 6.3s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 19.9it/s 0.2s
#                    all      0.812          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      13/
#                    all      0.958          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      72/100     0.279G    0.02787          8        224: 100% ━━━━━━━━━━━━ 45/45 7.1it/s 6.3s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 25.5it/s 0.1s
#                    all      0.927          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      73/100     0.279G    0.03703          8        224: 100% ━━━━━━━━━━━━ 45/45 9.0it/s 5.0s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 22.5it/s 0.1s
#                    all      0.917          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      74/100     0.279G    0.03451          8        224: 100% ━━━━━━━━━━━━ 45/45 7.0it/s 6.4s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 21.4it/s 0.1s
#                    all      0.938          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      75/100     0.279G    0.03187          8        224: 100% ━━━━━━━━━━━━ 45/45 8.7it/s 5.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 18.3it/s 0.2s
#                    all      0.896          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      76/100     0.279G    0.02758          8        224: 100% ━━━━━━━━━━━━ 45/45 7.0it/s 6.4s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 19.3it/s 0.2s
#                    all      0.958          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      77/100     0.279G    0.03146          8        224: 100% ━━━━━━━━━━━━ 45/45 9.0it/s 5.0s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 24.3it/s 0.1s
#                    all      0.938          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      78/100     0.279G    0.02601          8        224: 100% ━━━━━━━━━━━━ 45/45 7.2it/s 6.3s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 23.3it/s 0.1s
#                    all      0.927          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      79/100     0.279G    0.04453          8        224: 100% ━━━━━━━━━━━━ 45/45 8.7it/s 5.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 22.1it/s 0.1s
#                    all      0.927          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      80/100     0.279G    0.01411          8        224: 100% ━━━━━━━━━━━━ 45/45 6.9it/s 6.5s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 21.1it/s 0.1s
#                    all      0.938          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      81/100     0.279G    0.02546          8        224: 100% ━━━━━━━━━━━━ 45/45 8.7it/s 5.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 35.5it/s 0.1s
#                    all      0.958          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      82/100     0.279G    0.02034          8        224: 100% ━━━━━━━━━━━━ 45/45 7.2it/s 6.3s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 21.5it/s 0.1s
#                    all      0.948          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      83/100     0.279G     0.0366          8        224: 100% ━━━━━━━━━━━━ 45/45 8.5it/s 5.3s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 24.4it/s 0.1s
#                    all      0.958          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      84/100     0.279G    0.01788          8        224: 100% ━━━━━━━━━━━━ 45/45 7.0it/s 6.4s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 31.0it/s 0.1s
#                    all      0.927          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      85/100     0.279G    0.02806          8        224: 100% ━━━━━━━━━━━━ 45/45 8.5it/s 5.3s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 25.6it/s 0.1s
#                    all      0.938          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      86/100     0.279G    0.02156          8        224: 100% ━━━━━━━━━━━━ 45/45 6.9it/s 6.6s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 22.6it/s 0.1s
#                    all      0.927          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      87/100     0.279G    0.02297          8        224: 100% ━━━━━━━━━━━━ 45/45 8.7it/s 5.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 19.8it/s 0.2s
#                    all      0.938          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      88/100     0.279G    0.02221          8        224: 100% ━━━━━━━━━━━━ 45/45 7.1it/s 6.4s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 33.3it/s 0.1s
#                    all      0.948          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      89/100     0.279G    0.02295          8        224: 100% ━━━━━━━━━━━━ 45/45 8.4it/s 5.4s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 29.0it/s 0.1s
#                    all      0.927          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      90/100     0.279G    0.02529          8        224: 100% ━━━━━━━━━━━━ 45/45 7.0it/s 6.4s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 22.2it/s 0.1s
#                    all      0.927          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      91/100     0.279G    0.00879          8        224: 100% ━━━━━━━━━━━━ 45/45 8.0it/s 5.6s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 22.1it/s 0.1s
#                    all      0.938          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      92/100     0.279G    0.01641          8        224: 100% ━━━━━━━━━━━━ 45/45 7.2it/s 6.3s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 21.5it/s 0.1s
#                    all      0.969          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      93/100     0.279G    0.03032          8        224: 100% ━━━━━━━━━━━━ 45/45 8.6it/s 5.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 32.7it/s 0.1s
#                    all      0.958          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      94/100     0.279G    0.01555          8        224: 100% ━━━━━━━━━━━━ 45/45 6.6it/s 6.8s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 26.4it/s 0.1s
#                    all      0.958          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      95/100     0.279G    0.01545          8        224: 100% ━━━━━━━━━━━━ 45/45 8.6it/s 5.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 32.4it/s 0.1s
#                    all      0.948          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      96/100     0.279G    0.01408          8        224: 100% ━━━━━━━━━━━━ 45/45 7.0it/s 6.4s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 25.5it/s 0.1s
#                    all      0.927          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      97/100     0.279G     0.0114          8        224: 100% ━━━━━━━━━━━━ 45/45 8.7it/s 5.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 26.4it/s 0.1s
#                    all      0.948          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      98/100     0.279G    0.01167          8        224: 100% ━━━━━━━━━━━━ 45/45 6.7it/s 6.8s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 23.3it/s 0.1s
#                    all      0.938          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      99/100     0.279G    0.04844          8        224: 100% ━━━━━━━━━━━━ 45/45 8.0it/s 5.6s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 25.0it/s 0.1s
#                    all      0.958          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#     100/100     0.279G    0.01719          8        224: 100% ━━━━━━━━━━━━ 45/45 6.9it/s 6.5s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 23.7it/s 0.1s
#                    all      0.958          1
#
# 100 epochs completed in 0.184 hours.
# Optimizer stripped from /content/runs/classify/train/weights/last.pt, 3.2MB
# Optimizer stripped from /content/runs/classify/train/weights/best.pt, 3.2MB
#
# Validating /content/runs/classify/train/weights/best.pt...
# Ultralytics 8.4.21 🚀 Python-3.12.12 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# YOLO26n-cls summary (fused): 47 layers, 1,528,586 parameters, 0 gradients, 3.2 GFLOPs
# train: /content/converse_vans_classification/train... found 712 images in 2 classes ✅
# val: /content/converse_vans_classification/val... found 96 images in 2 classes ✅
# test: /content/converse_vans_classification/test... found 86 images in 2 classes ✅
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 19.4it/s 0.2s
#                    all      0.969          1
# Speed: 0.2ms preprocess, 0.8ms inference, 0.0ms loss, 0.0ms postprocess per image
# Results saved to /content/runs/classify/train
# 💡 Learn more at https://docs.ultralytics.com/modes/train

# %% [markdown]
# Here are trained models.

# %%
# !ls runs/classify/train/weights
# Out:
# best.pt  last.pt

# %% [markdown]
# Move the best model to the current folder and export to a Core ML model.

# %%
# !mv runs/classify/train/weights/best.pt .

# %%
# !yolo export model=best.pt format=coreml
# Out:
# Ultralytics 8.4.21 🚀 Python-3.12.12 torch-2.10.0+cu128 CPU (Intel Xeon CPU @ 2.00GHz)
# 💡 ProTip: Export to OpenVINO format for best performance on Intel hardware. Learn more at https://docs.ultralytics.com/integrations/openvino/
# YOLO26n-cls summary (fused): 47 layers, 1,528,586 parameters, 0 gradients, 3.2 GFLOPs
#
# PyTorch: starting from 'best.pt' with input shape (1, 3, 224, 224) BCHW and output shape(s) (1, 2) (3.0 MB)
# requirements: Ultralytics requirement ['coremltools>=9.0'] not found, attempting AutoUpdate...
# Using Python 3.12.12 environment at: /usr
# Resolved 12 packages in 310ms
# Prepared 3 packages in 139ms
# Installed 3 packages in 16ms
#  + cattrs==26.1.0
#  + coremltools==9.0
#  + pyaml==26.2.1
#
# requirements: AutoUpdate success ✅ 0.8s
# WARNING ⚠️ requirements: Restart runtime or rerun command for updates to take effect
#
# scikit-learn version 1.6.1 is not supported. Minimum required version: 0.17. Maximum required version: 1.5.1. Disabling scikit-learn conversion API.
# XGBoost version 3.2.0 has not been tested with coremltools. You may run into unexpected errors. XGBoost 1.4.2 is the most recent version that has been tested.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1772931023.804424    4838 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1772931023.811340    4838 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1772931023.829622    4838 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1772931023.829647    4838 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1772931023.829653    4838 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1772931023.829656    4838 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# TensorFlow version 2.19.0 has not been tested with coremltools. You may run into unexpected errors. TensorFlow 2.12.0 is the most recent version that has been tested.
# Torch version 2.10.0+cu128 has not been tested with coremltools. You may run into unexpected errors. Torch 2.7.0 is the most recent version that has been tested.
# WARNING:coremltools:Failed to load _MLModelProxy: No module named 'coremltools.libcoremlpython'
# WARNING:coremltools:Failed to load _MLCPUComputeDeviceProxy: No module named 'coremltools.libcoremlpython'
# WARNING:coremltools:Failed to load _MLGPUComputeDeviceProxy: No module named 'coremltools.libcoremlpython'
# WARNING:coremltools:Failed to load _MLNeuralEngineComputeDeviceProxy: No module named 'coremltools.libcoremlpython'
# WARNING:coremltools:Failed to load _MLModelProxy: No module named 'coremltools.libcoremlpython'
# WARNING:coremltools:Failed to load _MLComputePlanProxy: No module named 'coremltools.libcoremlpython'
# WARNING:coremltools:Failed to load _MLModelProxy: No module named 'coremltools.libcoremlpython'
# WARNING:coremltools:Failed to load _MLModelAssetProxy: No module named 'coremltools.libcoremlpython'
# /usr/local/lib/python3.12/dist-packages/coremltools/optimize/torch/palettization/fake_palettize.py:82: SyntaxWarning: invalid escape sequence '\_'
#   n_bits (:obj:`int`): Number of palettization bits. There would be :math:`2^{n\_bits}` unique weights in the ``LUT``.
#
# CoreML: starting export with coremltools 9.0...
# Converting PyTorch Frontend ==> MIL Ops: 100% 361/362 [00:00<00:00, 1896.08 ops/s]
# Running MIL frontend_pytorch pipeline: 100% 5/5 [00:00<00:00, 111.20 passes/s]
# Running MIL default pipeline:  12% 11/95 [00:00<00:00, 103.96 passes/s]/usr/local/lib/python3.12/dist-packages/coremltools/converters/mil/mil/passes/defs/preprocess.py:273: UserWarning: Output, '564', of the source model, has been renamed to 'var_564' in the Core ML model.
#   warnings.warn(msg.format(var.name, new_name))
# Running MIL default pipeline: 100% 95/95 [00:01<00:00, 74.89 passes/s]
# Running MIL backend_mlprogram pipeline: 100% 12/12 [00:00<00:00, 196.03 passes/s]
# CoreML: export success ✅ 16.8s, saved as 'best.mlpackage' (3.0 MB)
#
# Export complete (16.9s)
# Results saved to /content
# Predict:         yolo predict task=classify model=best.mlpackage imgsz=224
# Validate:        yolo val task=classify model=best.mlpackage imgsz=224 data=converse_vans_classification
# Visualize:       https://netron.app
# 💡 Learn more at https://docs.ultralytics.com/modes/export

# %% [markdown]
# Zip the Core ML model and download it from the File browser at the left hand. You can auto label images using the Core ML model on RectLabel.

# %%
# !zip -r best.mlpackage.zip best.mlpackage
# Out:
#   adding: best.mlpackage/ (stored 0%)
#   adding: best.mlpackage/Manifest.json (deflated 60%)
#   adding: best.mlpackage/Data/ (stored 0%)
#   adding: best.mlpackage/Data/com.apple.CoreML/ (stored 0%)
#   adding: best.mlpackage/Data/com.apple.CoreML/model.mlmodel (deflated 86%)
#   adding: best.mlpackage/Data/com.apple.CoreML/weights/ (stored 0%)
#   adding: best.mlpackage/Data/com.apple.CoreML/weights/weight.bin (deflated 7%)
