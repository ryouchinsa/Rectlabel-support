# %% [markdown]
# <a href="https://colab.research.google.com/github/ryouchinsa/Rectlabel-support/blob/master/notebooks/train_yolo26_instance_segmentation_on_custom_dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # How to Train a YOLO26 Instance Segmentation Model with Custom Data
#
# We will show you how to train a YOLO26 instance segmentation model with your images and annotations and export to a Core ML model which can be used for auto labeling on RectLabel.

# %% [markdown]
# ### Use GPU
#
# Let's make sure that we have access to GPU. We can use `nvidia-smi` command to do that. In case of any problems navigate to `Runtime` -> `Change runtime type` -> `Hardware accelerator`, set it to `GPU`, and then click `Save`.

# %%
# !nvidia-smi
# Out:
# Sun Mar  8 17:06:10 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   51C    P8             10W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %% [markdown]
# ### Install YOLO26

# %%
# %pip install -q ultralytics
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 70.9 MB/s eta 0:00:00

# %% [markdown]
# ### Download training images and annotations
#
# Download training images and annotations. You can use these or replace them with your own data.

# %%
# !mkdir datasets
# %cd datasets
# !wget -q https://huggingface.co/datasets/rectlabel/datasets/resolve/main/donut.zip
# !unzip -q donut.zip
# %cd ..
# Out:
# /content/datasets
# /content

# %% [markdown]
# ### Fine-tune YOLO26 on custom dataset
#
# Create a workspace folder and start training from the workspace folder. Make sure the datasets path in the yaml file.

# %%
# !mkdir workspace
# %cd workspace
# !mv ../datasets/donut/donut.yaml .
# Out:
# /content/workspace

# %%
# !yolo segment train data=donut.yaml model=yolo26n-seg.pt epochs=200
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolo26n-seg.pt to 'yolo26n-seg.pt': 100% ━━━━━━━━━━━━ 6.4MB 278.7MB/s 0.0s
# Ultralytics 8.4.21 🚀 Python-3.12.12 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# engine/trainer: agnostic_nms=False, amp=True, angle=1.0, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=donut.yaml, degrees=0.0, deterministic=True, device=None, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, end2end=None, epochs=200, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolo26n-seg.pt, momentum=0.937, mosaic=1.0, multi_scale=0.0, name=train, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=None, rect=False, resume=False, retina_masks=False, rle=1.0, save=True, save_conf=False, save_crop=False, save_dir=/content/workspace/runs/segment/train, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=segment, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Downloading https://ultralytics.com/assets/Arial.ttf to '/root/.config/Ultralytics/Arial.ttf': 100% ━━━━━━━━━━━━ 755.1KB 139.0MB/s 0.0s
# Overriding model.yaml nc=80 with nc=1
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      6640  ultralytics.nn.modules.block.C3k2            [32, 64, 1, False, 0.25]
#   3                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#   4                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   5                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   6                  -1  1     87040  ultralytics.nn.modules.block.C3k2            [128, 128, 1, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    346112  ultralytics.nn.modules.block.C3k2            [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5, 3, True]
#  10                  -1  1    249728  ultralytics.nn.modules.block.C2PSA           [256, 256, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1    119808  ultralytics.nn.modules.block.C3k2            [384, 128, 1, True]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1     34304  ultralytics.nn.modules.block.C3k2            [256, 64, 1, True]
#  17                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1     95232  ultralytics.nn.modules.block.C3k2            [192, 128, 1, True]
#  20                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1    463104  ultralytics.nn.modules.block.C3k2            [384, 256, 1, True, 0.5, True]
#  23        [16, 19, 22]  1    790431  ultralytics.nn.modules.head.Segment26        [1, 32, 64, 1, True, [64, 128, 256]]
# YOLO26n-seg summary: 309 layers, 3,053,055 parameters, 3,053,055 gradients, 10.2 GFLOPs
#
# Transferred 740/844 items from pretrained weights
# AMP: running Automatic Mixed Precision (AMP) checks...
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolo26n.pt to 'yolo26n.pt': 100% ━━━━━━━━━━━━ 5.3MB 223.9MB/s 0.0s
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1895.3±925.4 MB/s, size: 216.6 KB)
# train: Scanning /content/datasets/donut/train/labels... 31 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 31/31 1.7Kit/s 0.0s
# train: /content/datasets/donut/train/images/donuts_brooke-lark-5BbB3WPi128-unsplash_aug0.jpg: 1 duplicate labels removed
# train: /content/datasets/donut/train/images/donuts_brooke-lark-5BbB3WPi128-unsplash_aug1.jpg: 1 duplicate labels removed
# train: New cache created: /content/datasets/donut/train/labels.cache
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 936.1±731.0 MB/s, size: 241.0 KB)
# val: Scanning /content/datasets/donut/train/labels.cache... 31 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 31/31 1.6Mit/s 0.0s
# train: /content/datasets/donut/train/images/donuts_brooke-lark-5BbB3WPi128-unsplash_aug0.jpg: 1 duplicate labels removed
# train: /content/datasets/donut/train/images/donuts_brooke-lark-5BbB3WPi128-unsplash_aug1.jpg: 1 duplicate labels removed
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.002, momentum=0.9) with parameter groups 134 weight(decay=0.0), 154 weight(decay=0.0005), 154 bias(decay=0.0)
# Plotting labels to /content/workspace/runs/segment/train/labels.jpg...
# Image sizes 640 train, 640 val
# Using 2 dataloader workers
# Logging results to /content/workspace/runs/segment/train
# Starting training for 200 epochs...
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#       1/200      3.71G     0.6806      2.545      2.978   0.006188      6.436        200        640: 100% ━━━━━━━━━━━━ 2/2 11.6s/it 23.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 5.1s/it 5.1s
#                    all         31        169     0.0175      0.964      0.154      0.118     0.0176       0.97     0.0707     0.0465
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#       2/200      4.29G     0.6536       2.69      3.008   0.006359      6.329        174        640: 100% ━━━━━━━━━━━━ 2/2 1.8it/s 1.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 1.2it/s 0.9s
#                    all         31        169     0.0174      0.959      0.163      0.125     0.0177      0.976     0.0699     0.0456
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#       3/200       4.3G     0.7094      2.671      3.034   0.006311      6.353        177        640: 100% ━━━━━━━━━━━━ 2/2 2.0it/s 1.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 2.0it/s 0.5s
#                    all         31        169     0.0174      0.959      0.173      0.132     0.0177      0.976     0.0782     0.0479
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#       4/200       4.3G     0.5863      2.677      2.982   0.005907      6.267        181        640: 100% ━━━━━━━━━━━━ 2/2 2.4it/s 0.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 2.0it/s 0.5s
#                    all         31        169     0.0173      0.953      0.173       0.13     0.0177      0.976     0.0752     0.0473
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#       5
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#     190/200      4.33G     0.3048     0.3865     0.4448   0.002594     0.1288        194        640: 100% ━━━━━━━━━━━━ 2/2 1.5it/s 1.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 1.4it/s 0.7s
#                    all         31        169      0.976       0.95       0.99      0.985      0.976       0.95      0.981      0.969
# Closing dataloader mosaic
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#     191/200      4.33G      0.269     0.3273     0.6344   0.003198     0.1461         81        640: 100% ━━━━━━━━━━━━ 2/2 1.0s/it 2.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 1.8s/it 1.8s
#                    all         31        169      0.976       0.95       0.99      0.985      0.976       0.95      0.981      0.969
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#     192/200      4.33G     0.2817       0.46     0.6469   0.004551     0.1168         83        640: 100% ━━━━━━━━━━━━ 2/2 1.9it/s 1.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 1.4it/s 0.7s
#                    all         31        169      0.975      0.935      0.989      0.985      0.975      0.935      0.981      0.969
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#     193/200      4.33G     0.2508     0.3554     0.6505   0.003469     0.1577         83        640: 100% ━━━━━━━━━━━━ 2/2 2.8it/s 0.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 2.0it/s 0.5s
#                    all         31        169      0.975      0.935      0.989      0.985      0.975      0.935      0.981      0.969
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#     194/200      4.33G      0.227     0.3024     0.6003   0.002891     0.1111         94        640: 100% ━━━━━━━━━━━━ 2/2 2.7it/s 0.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 1.6it/s 0.6s
#                    all         31        169      0.981      0.935      0.989      0.984      0.981      0.935      0.981      0.968
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#     195/200      4.33G     0.2034     0.2743     0.6158   0.002807     0.1201         72        640: 100% ━━━━━━━━━━━━ 2/2 1.9it/s 1.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 1.5it/s 0.6s
#                    all         31        169      0.981      0.935      0.989      0.984      0.981      0.935      0.981      0.968
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#     196/200      4.33G      0.234     0.2925     0.6094   0.003234     0.1222         70        640: 100% ━━━━━━━━━━━━ 2/2 2.7it/s 0.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 1.9it/s 0.5s
#                    all         31        169      0.958      0.942      0.989      0.984      0.958      0.942      0.981      0.966
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#     197/200      4.33G     0.2159     0.2842     0.5673   0.002998     0.1095         79        640: 100% ━━━━━━━━━━━━ 2/2 2.9it/s 0.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 1.9it/s 0.5s
#                    all         31        169      0.958      0.942      0.989      0.984      0.958      0.942      0.981      0.966
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#     198/200      4.33G     0.2622     0.3681     0.6408   0.003526     0.1289         62        640: 100% ━━━━━━━━━━━━ 2/2 2.7it/s 0.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 1.9it/s 0.5s
#                    all         31        169      0.958      0.955       0.99      0.985      0.958      0.955      0.981      0.968
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#     199/200      4.33G     0.2149     0.3252     0.5998   0.002902     0.1132         87        640: 100% ━━━━━━━━━━━━ 2/2 2.8it/s 0.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 2.0it/s 0.5s
#                    all         31        169      0.958      0.955       0.99      0.985      0.958      0.955      0.981      0.968
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#     200/200      4.33G     0.2067     0.3314     0.5751   0.002489     0.1226         85        640: 100% ━━━━━━━━━━━━ 2/2 2.2it/s 0.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 1.9it/s 0.5s
#                    all         31        169      0.969      0.935       0.99      0.985      0.969      0.935      0.981      0.967
#
# 200 epochs completed in 0.121 hours.
# Optimizer stripped from /content/workspace/runs/segment/train/weights/last.pt, 6.6MB
# Optimizer stripped from /content/workspace/runs/segment/train/weights/best.pt, 6.6MB
#
# Validating /content/workspace/runs/segment/train/weights/best.pt...
# Ultralytics 8.4.21 🚀 Python-3.12.12 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# YOLO26n-seg summary (fused): 139 layers, 2,689,079 parameters, 0 gradients, 9.0 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 1.0it/s 1.0s
#                    all         31        169      0.961      0.941      0.987      0.978      0.961      0.941      0.989      0.976
# Speed: 0.2ms preprocess, 4.1ms inference, 0.0ms loss, 2.4ms postprocess per image
# Results saved to /content/workspace/runs/segment/train
# 💡 Learn more at https://docs.ultralytics.com/modes/train

# %% [markdown]
# Here are trained models.

# %%
# !ls runs/segment/train/weights
# Out:
# best.pt  last.pt

# %% [markdown]
# Move the best model to the current folder and export to a Core ML model.

# %%
# !mv runs/segment/train/weights/best.pt .

# %%
# !yolo export model=best.pt format=coreml
# Out:
# Ultralytics 8.4.21 🚀 Python-3.12.12 torch-2.10.0+cu128 CPU (Intel Xeon CPU @ 2.20GHz)
# 💡 ProTip: Export to OpenVINO format for best performance on Intel hardware. Learn more at https://docs.ultralytics.com/integrations/openvino/
# YOLO26n-seg summary (fused): 139 layers, 2,689,079 parameters, 0 gradients, 9.0 GFLOPs
#
# PyTorch: starting from 'best.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) ((1, 300, 38), (1, 32, 160, 160)) (6.3 MB)
# requirements: Ultralytics requirement ['coremltools>=9.0'] not found, attempting AutoUpdate...
# Using Python 3.12.12 environment at: /usr
# Resolved 12 packages in 157ms
# Prepared 3 packages in 119ms
# Installed 3 packages in 15ms
#  + cattrs==26.1.0
#  + coremltools==9.0
#  + pyaml==26.2.1
#
# requirements: AutoUpdate success ✅ 0.7s
# WARNING ⚠️ requirements: Restart runtime or rerun command for updates to take effect
#
# scikit-learn version 1.6.1 is not supported. Minimum required version: 0.17. Maximum required version: 1.5.1. Disabling scikit-learn conversion API.
# XGBoost version 3.2.0 has not been tested with coremltools. You may run into unexpected errors. XGBoost 1.4.2 is the most recent version that has been tested.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1772990096.369740    3199 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1772990096.376774    3199 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1772990096.395507    3199 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1772990096.395534    3199 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1772990096.395539    3199 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1772990096.395542    3199 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# TensorFlow version 2.19.0 has not been tested with coremltools. You may run into unexpected errors. TensorFlow 2.12.0 is the most recent version that has been tested.
# Torch version 2.10.0+cu128 has not been tested with coremltools. You may run into unexpected errors. Torch 2.7.0 is the most recent version that has been tested.
# WARNING:coremltools:Failed to load _MLModelProxy: No module named 'coremltools.libcoremlpython'
# WARNING:coremltools:Failed to load _MLCPUComputeDeviceProxy: No module named 'coremltools.libcoremlpython'
# WARNING:coremltools:Failed to load _MLGPUComputeDeviceProxy: No module named 'coremltools.libcoremlpython'
# WARNING:coremltools:Failed to load _MLNeuralEngineComputeDeviceProxy: No module named 'coremltools.libcoremlpython'
# WARNING:coremltools:Failed to load _MLModelProxy: No module named 'coremltools.libcoremlpython'
# WARNING:coremltools:Failed to load _MLComputePlanProxy: No module named 'coremltools.libcoremlpython'
# WARNING:coremltools:Failed to load _MLModelProxy: No module named 'coremltools.libcoremlpython'
# WARNING:coremltools:Failed to load _MLModelAssetProxy: No module named 'coremltools.libcoremlpython'
# /usr/local/lib/python3.12/dist-packages/coremltools/optimize/torch/palettization/fake_palettize.py:82: SyntaxWarning: invalid escape sequence '\_'
#   n_bits (:obj:`int`): Number of palettization bits. There would be :math:`2^{n\_bits}` unique weights in the ``LUT``.
#
# CoreML: starting export with coremltools 9.0...
# WARNING:coremltools:Tuple detected at graph output. This will be flattened in the converted model.
# Converting PyTorch Frontend ==> MIL Ops:  66% 698/1052 [00:00<00:00, 3478.63 ops/s]WARNING:coremltools:Saving value type of int64 into a builtin type of int32, might lose precision!
# Converting PyTorch Frontend ==> MIL Ops: 100% 1050/1052 [00:00<00:00, 3144.58 ops/s]
# Running MIL frontend_pytorch pipeline: 100% 5/5 [00:00<00:00, 65.86 passes/s]
# Running MIL default pipeline:   7% 7/95 [00:00<00:01, 68.20 passes/s]/usr/local/lib/python3.12/dist-packages/coremltools/converters/mil/mil/passes/defs/preprocess.py:273: UserWarning: Output, '1546', of the source model, has been renamed to 'var_1546' in the Core ML model.
#   warnings.warn(msg.format(var.name, new_name))
# /usr/local/lib/python3.12/dist-packages/coremltools/converters/mil/mil/passes/defs/preprocess.py:273: UserWarning: Output, '1626', of the source model, has been renamed to 'var_1626' in the Core ML model.
#   warnings.warn(msg.format(var.name, new_name))
# Running MIL default pipeline:  64% 61/95 [00:01<00:01, 17.32 passes/s]/usr/local/lib/python3.12/dist-packages/coremltools/converters/mil/mil/passes/defs/optimize_repeat_ops.py:433: RuntimeWarning: overflow encountered in cast
#   max(cur_range.low, tmp_range.low), min(cur_range.high, tmp_range.high)
# Running MIL default pipeline: 100% 95/95 [00:02<00:00, 34.52 passes/s]
# Running MIL backend_mlprogram pipeline: 100% 12/12 [00:00<00:00, 62.19 passes/s]
# CoreML: export success ✅ 20.7s, saved as 'best.mlpackage' (5.4 MB)
#
# Export complete (21.4s)
# Results saved to /content/workspace
# Predict:         yolo predict task=segment model=best.mlpackage imgsz=640
# Validate:        yolo val task=segment model=best.mlpackage imgsz=640 data=donut.yaml
# Visualize:       https://netron.app
# 💡 Learn more at https://docs.ultralytics.com/modes/export

# %% [markdown]
# Zip the Core ML model and download it from the File browser at the left hand. You can auto label images using the Core ML model on RectLabel.

# %%
# !zip -r best.mlpackage.zip best.mlpackage
# Out:
#   adding: best.mlpackage/ (stored 0%)
#   adding: best.mlpackage/Manifest.json (deflated 60%)
#   adding: best.mlpackage/Data/ (stored 0%)
#   adding: best.mlpackage/Data/com.apple.CoreML/ (stored 0%)
#   adding: best.mlpackage/Data/com.apple.CoreML/model.mlmodel (deflated 89%)
#   adding: best.mlpackage/Data/com.apple.CoreML/weights/ (stored 0%)
#   adding: best.mlpackage/Data/com.apple.CoreML/weights/weight.bin (deflated 8%)
