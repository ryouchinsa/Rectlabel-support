# %% [markdown]
# <a href="https://colab.research.google.com/github/ryouchinsa/Rectlabel-support/blob/master/notebooks/train_yolo26_object_detection_on_custom_dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # How to Train a YOLO26 Object Detection Model with Custom Data
#
# We will show you how to train a YOLO26 detection model with your images and annotations and export to a Core ML model which can be used for auto labeling on RectLabel.

# %% [markdown]
# ### Use GPU
#
# Let's make sure that we have access to GPU. We can use `nvidia-smi` command to do that. In case of any problems navigate to `Runtime` -> `Change runtime type` -> `Hardware accelerator`, set it to `GPU`, and then click `Save`.

# %%
# !nvidia-smi
# Out:
# Sun Mar 29 08:39:06 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   54C    P8             11W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %% [markdown]
# ### Install YOLO26

# %%
# !pip install -q ultralytics
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 33.6 MB/s eta 0:00:00

# %% [markdown]
# ### Download training images and annotations
#
# Download training images and annotations. You can use these or replace them with your own data.

# %%
# !mkdir datasets
# %cd datasets
# !wget -q https://huggingface.co/datasets/rectlabel/datasets/resolve/main/converse_vans_detection.zip
# !unzip -q converse_vans_detection.zip
# %cd ..
# Out:
# /content/datasets
# /content

# %% [markdown]
# ### Fine-tune YOLO26 on custom dataset
#
# Create a workspace folder and start training from the workspace folder. Make sure the datasets path in the yaml file.

# %%
# !mkdir workspace
# %cd workspace
# !mv ../datasets/converse_vans_detection/converse_vans_detection.yaml .
# Out:
# /content/workspace

# %%
# !yolo task=detect mode=train model=yolo26n.pt data=converse_vans_detection.yaml epochs=100 imgsz=640 plots=True
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolo26n.pt to 'yolo26n.pt': 100% ━━━━━━━━━━━━ 5.3MB 89.5MB/s 0.1s
# Ultralytics 8.4.31 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# engine/trainer: agnostic_nms=False, amp=True, angle=1.0, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=converse_vans_detection.yaml, degrees=0.0, deterministic=True, device=None, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, end2end=None, epochs=100, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolo26n.pt, momentum=0.937, mosaic=1.0, multi_scale=0.0, name=train, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=None, rect=False, resume=False, retina_masks=False, rle=1.0, save=True, save_conf=False, save_crop=False, save_dir=/content/workspace/runs/detect/train, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Downloading https://ultralytics.com/assets/Arial.ttf to '/root/.config/Ultralytics/Arial.ttf': 100% ━━━━━━━━━━━━ 755.1KB 30.2MB/s 0.0s
# Overriding model.yaml nc=80 with nc=2
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      6640  ultralytics.nn.modules.block.C3k2            [32, 64, 1, False, 0.25]
#   3                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#   4                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   5                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   6                  -1  1     87040  ultralytics.nn.modules.block.C3k2            [128, 128, 1, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    346112  ultralytics.nn.modules.block.C3k2            [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5, 3, True]
#  10                  -1  1    249728  ultralytics.nn.modules.block.C2PSA           [256, 256, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1    119808  ultralytics.nn.modules.block.C3k2            [384, 128, 1, True]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1     34304  ultralytics.nn.modules.block.C3k2            [256, 64, 1, True]
#  17                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1     95232  ultralytics.nn.modules.block.C3k2            [192, 128, 1, True]
#  20                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1    463104  ultralytics.nn.modules.block.C3k2            [384, 256, 1, True, 0.5, True]
#  23        [16, 19, 22]  1    241956  ultralytics.nn.modules.head.Detect           [2, 1, True, [64, 128, 256]]
# YOLO26n summary: 260 layers, 2,504,580 parameters, 2,504,580 gradients, 5.8 GFLOPs
#
# Transferred 606/708 items from pretrained weights
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 2064.8±1129.9 MB/s, size: 260.6 KB)
# train: Scanning /content/datasets/converse_vans_detection/train/labels... 351 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 351/351 2.1Kit/s 0.2s
# train: New cache created: /content/datasets/converse_vans_detection/train/labels.cache
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1262.9±899.0 MB/s, size: 162.6 KB)
# val: Scanning /content/datasets/converse_vans_detection/valid/labels... 44 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 44/44 1.6Kit/s 0.0s
# val: New cache created: /content/datasets/converse_vans_detection/valid/labels.cache
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.001667, momentum=0.9) with parameter groups 114 weight(decay=0.0), 126 weight(decay=0.0005), 126 bias(decay=0.0)
# Plotting labels to /content/workspace/runs/detect/train/labels.jpg...
# Image sizes 640 train, 640 val
# Using 2 dataloader workers
# Logging results to /content/workspace/runs/detect/train
# Starting training for 100 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       1/100       2.4G     0.9713      5.348   0.006676         64        640: 100% ━━━━━━━━━━━━ 22/22 1.4s/it 30.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 3.9s/it 7.8s
#                    all         44         86    0.00468      0.618     0.0636     0.0445
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       2/100      2.92G      1.043      4.568   0.007362         65        640: 100% ━━━━━━━━━━━━ 22/22 2.6it/s 8.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 4.8it/s 0.4s
#                    all         44         86    0.00495      0.661      0.126     0.0853
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       3/100      2.92G      1.111      4.223   0.007989         48        640: 100% ━━━━━━━━━━━━ 22/22 3.0it/s 7.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 3.6it/s 0.6s
#                    all         44         86      0.762     0.0673      0.208      0.145
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       4/100      2.92G      1.127      3.805   0.008331         66        640: 100% ━━━━━━━━━━━━ 22/22 2.6it/s 8.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 4.0it/s 0.5s
#                    all         44         86      0.871      0.111      0.298      0.188
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       5/100      2.92G      1.156       3.47   0.008452         55        640: 100% ━━━━━━━━━━━━ 22/22 2.6it/s 8.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 4.9it/s 0.4s
#                    all         44         86      0.291        0.3      0.234       0.14
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       6/100      2.92G      1.129      3.182   0.008198         65        640: 100% ━━━━━━━━━━━━ 22/22 2.9it/s 7.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.6it/s 0.8s
#                    all         44         86      0.369      0.325      0.307      0.202
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       7/100      2.92G      1.112      2.915   0.008712         64        640: 100% ━━━━━━━━━━━━ 22/22 3.0it/s 7.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 4.2it/s 0.5s
#                    all         44         86      0.376       0.45      0.328      0.194
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       8/100      2.92G      1.111      2.654   0.008331         74        640: 100% ━━━━━━━━━━━━ 22/22 2.6it/s 8.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 4.6it/s 0.4s
#                    all         44         86      0.388      0.384      0.337      0.223
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       9/100      2.92G      1.073      2.536   0.008424         60        640: 100% ━━━━━━━━━━━━ 22/22 2.8it/s 7.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.4it/s 0.8s
#                    all         44         86      0.353       0.38      0.312      0.223
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      10/100      2.92G      1.089      2.362   0.007771         57        640: 100% ━━━━━━━━━━━━ 22/22 3.0it/s 7.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 5.6it/s 0.4s
#                    all         44         86      0.373      0.494      0.385      0.259
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      11/100      2.92G      1.087      2.209   0.008747         61        640: 100% ━━━━━━━━━━━━ 22/22 2.6it/s 8.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 3.4it/s 0.6s
#                    all         44         86       0.43      0.444      0.409       0.28
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      12/100      2.92G      1.066       2.11   0.008359         50        640: 100% ━━━━━━━━━━━━ 22/22 2.7it/s 8.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.6it/s 0.8s
#                    all         44         86       0.49      0.497       0.43      0.283
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      13/100      2.92G      1.085      1.993   0.007837         55        640: 100% ━━━━━━━━━━━━ 22/22 3.0it/s 7.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 4.0it/s 0.5s
#                    all         44         86      0.536      0.509      0.486      0.321
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      14/100      2.92G      1.047      1.861   0.007837         43        640: 100% ━━━━━━━━━━━━ 22/22 2.6it/s 8.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 5.8it/s 0.3s
#                    all         44         86       0.56        0.5      0.558      0.372
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      15/100      2.92G      1.043      1.725   0.007344         49        640: 100% ━━━━━━━━━━━━ 22/22 2.6it/s 8.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 3.6it/s 0.6s
#                    all         44         86      0.477      0.579       0.51      0.313
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      16/100      2.92G       1.05      1.602   0.007775         59        640: 100% ━━━━━━━━━━━━ 22/22 3.1it/s 7.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 3.8it/s 0.5s
#                    all         44         86      0.643      0.624      0.633      0.441
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      17/100      2.92G       1.04      1.562   0.008092         57        640: 100% ━━━━━━━━━━━━ 22/22 2.6it/s 8.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 4.4it/s 0.5s
#                    all         44         86      0.542      0.563      0.568      0.413
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      18/100      2.92G      1.066      1.575   0.008378         47        640: 100% ━━━━━━━━━━━━ 22/22 2.5it/s 8.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 6.5it/s 0.3s
#                    all         44         86      0.522      0.594       0.57      0.391
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      19/100      2
0.67
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      99/100      2.92G     0.4602     0.2699   0.003233         30        640: 100% ━━━━━━━━━━━━ 22/22 2.6it/s 8.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 4.8it/s 0.4s
#                    all         44         86      0.861       0.78      0.863      0.673
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     100/100      2.92G     0.4469     0.2832    0.00312         28        640: 100% ━━━━━━━━━━━━ 22/22 2.9it/s 7.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 3.0it/s 0.7s
#                    all         44         86      0.908      0.716      0.857      0.676
#
# 100 epochs completed in 0.263 hours.
# Optimizer stripped from /content/workspace/runs/detect/train/weights/last.pt, 5.4MB
# Optimizer stripped from /content/workspace/runs/detect/train/weights/best.pt, 5.4MB
#
# Validating /content/workspace/runs/detect/train/weights/best.pt...
# Ultralytics 8.4.31 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# YOLO26n summary (fused): 122 layers, 2,375,226 parameters, 0 gradients, 5.2 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 3.6it/s 0.6s
#                    all         44         86      0.909      0.725      0.858      0.676
# sneakers-converse-black         18         34      0.967      0.794      0.919      0.729
#    sneakers-vans-black         26         52       0.85      0.656      0.796      0.624
# Speed: 0.2ms preprocess, 3.8ms inference, 0.0ms loss, 0.3ms postprocess per image
# Results saved to /content/workspace/runs/detect/train
# 💡 Learn more at https://docs.ultralytics.com/modes/train

# %% [markdown]
# Here are trained models.

# %%
# !ls runs/detect/train/weights
# Out:
# best.pt  last.pt

# %% [markdown]
# Move the best model to the current folder and export to a Core ML model.

# %%
# !mv runs/detect/train/weights/best.pt .

# %%
# !yolo export model=best.pt format=coreml
# Out:
# Ultralytics 8.4.31 🚀 Python-3.12.13 torch-2.10.0+cu128 CPU (Intel Xeon CPU @ 2.00GHz)
# 💡 ProTip: Export to OpenVINO format for best performance on Intel hardware. Learn more at https://docs.ultralytics.com/integrations/openvino/
# YOLO26n summary (fused): 122 layers, 2,375,226 parameters, 0 gradients, 5.2 GFLOPs
#
# PyTorch: starting from 'best.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 300, 6) (5.1 MB)
# requirements: Ultralytics requirement ['coremltools>=9.0'] not found, attempting AutoUpdate...
# Using Python 3.12.13 environment at: /usr
# Resolved 12 packages in 218ms
# Prepared 3 packages in 131ms
# Installed 3 packages in 23ms
#  + cattrs==26.1.0
#  + coremltools==9.0
#  + pyaml==26.2.1
#
# requirements: AutoUpdate success ✅ 0.8s
# WARNING ⚠️ requirements: Restart runtime or rerun command for updates to take effect
#
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1774774620.100271    5266 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1774774620.107193    5266 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1774774620.124937    5266 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1774774620.124963    5266 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1774774620.124966    5266 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1774774620.124970    5266 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# /usr/local/lib/python3.12/dist-packages/coremltools/optimize/torch/palettization/fake_palettize.py:82: SyntaxWarning: invalid escape sequence '\_'
#   n_bits (:obj:`int`): Number of palettization bits. There would be :math:`2^{n\_bits}` unique weights in the ``LUT``.
#
# CoreML: starting export with coremltools 9.0...
# Converting PyTorch Frontend ==> MIL Ops: 100% 932/933 [00:00<00:00, 3225.90 ops/s]
# Running MIL frontend_pytorch pipeline: 100% 5/5 [00:00<00:00, 80.75 passes/s]
# Running MIL default pipeline:   7% 7/95 [00:00<00:01, 68.26 passes/s]/usr/local/lib/python3.12/dist-packages/coremltools/converters/mil/mil/passes/defs/preprocess.py:273: UserWarning: Output, '1440', of the source model, has been renamed to 'var_1440' in the Core ML model.
#   warnings.warn(msg.format(var.name, new_name))
# Running MIL default pipeline:  65% 62/95 [00:01<00:01, 18.62 passes/s]/usr/local/lib/python3.12/dist-packages/coremltools/converters/mil/mil/passes/defs/optimize_repeat_ops.py:433: RuntimeWarning: overflow encountered in cast
#   max(cur_range.low, tmp_range.low), min(cur_range.high, tmp_range.high)
# Running MIL default pipeline: 100% 95/95 [00:02<00:00, 37.51 passes/s]
# Running MIL backend_mlprogram pipeline: 100% 12/12 [00:00<00:00, 76.31 passes/s]
# CoreML: export success ✅ 19.6s, saved as 'best.mlpackage' (4.8 MB)
#
# Export complete (20.3s)
# Results saved to /content/workspace
# Predict:         yolo predict task=detect model=best.mlpackage imgsz=640
# Validate:        yolo val task=detect model=best.mlpackage imgsz=640 data=converse_vans_detection.yaml
# Visualize:       https://netron.app
# 💡 Learn more at https://docs.ultralytics.com/modes/export

# %% [markdown]
# Zip the Core ML model and download it from the File browser at the left hand. You can auto label images using the Core ML model on RectLabel.

# %%
# !zip -r best.mlpackage.zip best.mlpackage
# Out:
#   adding: best.mlpackage/ (stored 0%)
#   adding: best.mlpackage/Manifest.json (deflated 59%)
#   adding: best.mlpackage/Data/ (stored 0%)
#   adding: best.mlpackage/Data/com.apple.CoreML/ (stored 0%)
#   adding: best.mlpackage/Data/com.apple.CoreML/model.mlmodel (deflated 88%)
#   adding: best.mlpackage/Data/com.apple.CoreML/weights/ (stored 0%)
#   adding: best.mlpackage/Data/com.apple.CoreML/weights/weight.bin (deflated 8%)
