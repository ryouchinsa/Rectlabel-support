# %% [markdown]
# # How to Train a YOLO26 Object Detection Model with Custom Data
#
# We will show you how to train a YOLO26 detection model with your images and annotations and export to a Core ML model which can be used for auto labeling on RectLabel.

# %% [markdown]
# ### Use GPU
#
# Let's make sure that we have access to GPU. We can use `nvidia-smi` command to do that. In case of any problems navigate to `Runtime` -> `Change runtime type` -> `Hardware accelerator`, set it to `GPU`, and then click `Save`.

# %%
# !nvidia-smi
# Out:
# Sun Feb 22 21:47:44 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   32C    P8              8W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %% [markdown]
# ### Install YOLO26

# %%
# %pip install -q ultralytics

# %% [markdown]
# ### Download training images and annotations
#
# Download training images and annotations. You can use these or replace them with your own data.

# %%
# !mkdir datasets
# %cd datasets
# !wget -q https://huggingface.co/datasets/rectlabel/datasets/resolve/main/converse_vans_detection.zip
# !unzip -q converse_vans_detection.zip
# %cd ..
# Out:
# /content/datasets
# /content

# %% [markdown]
# ## Fine-tune YOLO26 on custom dataset
#
# Create a workspace folder and start training from the workspace folder. Make sure the datasets path in the yaml file.

# %%
# !mkdir workspace
# %cd workspace
# !mv ../datasets/converse_vans_detection/converse_vans_detection.yaml .
# Out:
# /content/workspace

# %%
# !yolo task=detect mode=train model=yolo26n.pt data=converse_vans_detection.yaml epochs=100 imgsz=640 plots=True
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolo26n.pt to 'yolo26n.pt': 100% ━━━━━━━━━━━━ 5.3MB 91.0MB/s 0.1s
# Ultralytics 8.4.14 🚀 Python-3.12.12 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# engine/trainer: agnostic_nms=False, amp=True, angle=1.0, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=converse_vans_detection.yaml, degrees=0.0, deterministic=True, device=None, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, end2end=None, epochs=100, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolo26n.pt, momentum=0.937, mosaic=1.0, multi_scale=0.0, name=train, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=None, rect=False, resume=False, retina_masks=False, rle=1.0, save=True, save_conf=False, save_crop=False, save_dir=/content/workspace/runs/detect/train, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Downloading https://ultralytics.com/assets/Arial.ttf to '/root/.config/Ultralytics/Arial.ttf': 100% ━━━━━━━━━━━━ 755.1KB 27.6MB/s 0.0s
# Overriding model.yaml nc=80 with nc=2
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      6640  ultralytics.nn.modules.block.C3k2            [32, 64, 1, False, 0.25]
#   3                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#   4                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   5                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   6                  -1  1     87040  ultralytics.nn.modules.block.C3k2            [128, 128, 1, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    346112  ultralytics.nn.modules.block.C3k2            [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5, 3, True]
#  10                  -1  1    249728  ultralytics.nn.modules.block.C2PSA           [256, 256, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1    119808  ultralytics.nn.modules.block.C3k2            [384, 128, 1, True]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1     34304  ultralytics.nn.modules.block.C3k2            [256, 64, 1, True]
#  17                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1     95232  ultralytics.nn.modules.block.C3k2            [192, 128, 1, True]
#  20                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1    463104  ultralytics.nn.modules.block.C3k2            [384, 256, 1, True, 0.5, True]
#  23        [16, 19, 22]  1    241956  ultralytics.nn.modules.head.Detect           [2, 1, True, [64, 128, 256]]
# YOLO26n summary: 260 layers, 2,504,580 parameters, 2,504,580 gradients, 5.8 GFLOPs
#
# Transferred 606/708 items from pretrained weights
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 2596.4±722.4 MB/s, size: 183.2 KB)
# train: Scanning /content/datasets/converse_vans_detection/train/labels... 351 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 351/351 1.9Kit/s 0.2s
# train: New cache created: /content/datasets/converse_vans_detection/train/labels.cache
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Fast image access ✅ (ping: 0.1±0.1 ms, read: 882.0±706.1 MB/s, size: 252.8 KB)
# val: Scanning /content/datasets/converse_vans_detection/val/labels... 44 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 44/44 942.4it/s 0.0s
# val: New cache created: /content/datasets/converse_vans_detection/val/labels.cache
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.001667, momentum=0.9) with parameter groups 114 weight(decay=0.0), 126 weight(decay=0.0005), 126 bias(decay=0.0)
# Plotting labels to /content/workspace/runs/detect/train/labels.jpg...
# Image sizes 640 train, 640 val
# Using 2 dataloader workers
# Logging results to /content/workspace/runs/detect/train
# Starting training for 100 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       1/100       2.4G      1.022      5.432    0.00721         53        640: 100% ━━━━━━━━━━━━ 22/22 1.5s/it 31.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 3.8s/it 7.5s
#                    all         44         91    0.00687       0.69      0.063     0.0392
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       2/100      2.92G     0.9917      4.631   0.006837         56        640: 100% ━━━━━━━━━━━━ 22/22 2.4it/s 9.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 4.9it/s 0.4s
#                    all         44         91    0.00658       0.83      0.125     0.0905
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       3/100      2.92G      1.085      4.306   0.008221         48        640: 100% ━━━━━━━━━━━━ 22/22 2.4it/s 9.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 4.3it/s 0.5s
#                    all         44         91      0.029      0.847      0.217      0.152
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       4/100      2.92G      1.087      3.738   0.007943         58        640: 100% ━━━━━━━━━━━━ 22/22 2.8it/s 7.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 4.9it/s 0.4s
#                    all         44         91      0.371      0.215      0.206      0.124
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       5/100      2.92G      1.094      3.433   0.007868         59        640: 100% ━━━━━━━━━━━━ 22/22 2.6it/s 8.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 4.3it/s 0.5s
#                    all         44         91      0.336       0.31      0.243      0.158
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       6/100      2.92G      1.151      3.225    0.00768         65        640: 100% ━━━━━━━━━━━━ 22/22 2.5it/s 8.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 3.1it/s 0.6s
#                    all         44         91      0.436      0.393      0.325      0.185
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       7/100      2.92G      1.193       2.96   0.008672         55        640: 100% ━━━━━━━━━━━━ 22/22 2.9it/s 7.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.5it/s 0.8s
#                    all         44         91      0.403      0.369      0.352      0.216
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       8/100      2.92G       1.13      2.805   0.008446         71        640: 100% ━━━━━━━━━━━━ 22/22 2.8it/s 7.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 4.8it/s 0.4s
#                    all         44         91      0.362      0.424      0.357      0.254
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       9/100      2.92G       1.08      2.523   0.008262         67        640: 100% ━━━━━━━━━━━━ 22/22 2.5it/s 8.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 4.0it/s 0.5s
#                    all         44         91      0.432      0.412      0.389      0.244
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      10/100      2.92G      1.097      2.366   0.007843         51        640: 100% ━━━━━━━━━━━━ 22/22 2.5it/s 8.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 4.1it/s 0.5s
#                    all         44         91      0.513      0.459      0.416      0.259
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      11/100      2.92G      1.071      2.169   0.007692         80        640: 100% ━━━━━━━━━━━━ 22/22 3.0it/s 7.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 4.0it/s 0.5s
#                    all         44         91      0.449      0.538      0.467      0.317
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      12/100      2.92G      1.094       2.14   0.007977         53        640: 100% ━━━━━━━━━━━━ 22/22 2.6it/s 8.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 3.2it/s 0.6s
#                    all         44         91      0.479      0.459      0.404       0.27
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      13/100      2.92G      1.085      1.931   0.007997         53        640: 100% ━━━━━━━━━━━━ 22/22 2.7it/s 8.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 3.3it/s 0.6s
#                    all         44         91      0.429      0.611      0.494      0.306
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      14/100      2.92G       1.12      1.846   0.008346         54        640: 100% ━━━━━━━━━━━━ 22/22 2.7it/s 8.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.9it/s 0.7s
#                    all         44         91      0.484       0.55      0.491       0.31
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      15/100      2.92G      1.009      1.698   0.007542         53        640: 100% ━━━━━━━━━━━━ 22/22 3.0it/s 7.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 3.5it/s 0.6s
#                    all         44         91       0.52       0.56      0.498      0.323
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      16/100      2.92G       1.04      1.654   0.007756         53        640: 100% ━━━━━━━━━━━━ 22/22 2.5it/s 8.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 4.0it/s 0.5s
#                    all         44         91      0.601      0.528      0.563      0.373
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      17/100      2.92G      1.036      1.589   0.007563         61        640: 100% ━━━━━━━━━━━━ 22/22 2.6it/s 8.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 4.0it/s 0.5s
#                    all         44         91      0.576       0.48      0.466      0.297
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      18/100      2.92G      1.016      1.489    0.00753         44        640: 100% ━━━━━━━━━━━━ 22/22 2.9it/s 7.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 3.1it/s 0.6s
#                    all         44         91      0.702      0.513      0.587      0.414
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      19/100      2.92G      1.031      1.423   0.007394         51        640: 100% ━━━━━━━━━━━━ 22/22 2.7it/s 8.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 5.8it/s 0.3s
#                    all         44         91      0.702      0.501      0.563      0.386
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      20/100      2.92G       1.01      1.332   0.007161         52        640: 100% ━━━━━━━━━━━━ 22/22 2.5it/s 8.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 4.2it/s 0.5s
#                    all         44         91      0.569      0.623      0.556      0.366
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      21/100      2.92G       0.96      1.219   0.007131         42        640: 100% ━━━━━━━━━━━━ 22/22 2.6it/s 8.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.7it/s 0.7s
#                    all         44         91      0.682      0.519      0.625       0.44
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      22/100      2.92G      1.005      1.203    0.00731         44        640: 100% ━━━━━━━━━━━━ 22/22 3.0it/s 7.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 3.4it/s 0.6s
#                    all         44         91      0.473      0.657      0.528      0.355
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      23/100      2
weights
# Out:
# best.pt  last.pt

# %% [markdown]
# Move the best model to the current folder and export to a Core ML model.

# %%
# !mv runs/detect/train/weights/best.pt .

# %%
# !yolo export model=best.pt format=coreml
# Out:
# Ultralytics 8.4.14 🚀 Python-3.12.12 torch-2.10.0+cu128 CPU (Intel Xeon CPU @ 2.00GHz)
# 💡 ProTip: Export to OpenVINO format for best performance on Intel hardware. Learn more at https://docs.ultralytics.com/integrations/openvino/
# YOLO26n summary (fused): 122 layers, 2,375,226 parameters, 0 gradients, 5.2 GFLOPs
#
# PyTorch: starting from 'best.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 300, 6) (5.1 MB)
# requirements: Ultralytics requirement ['coremltools>=9.0'] not found, attempting AutoUpdate...
# Using Python 3.12.12 environment at: /usr
# Resolved 12 packages in 260ms
# Prepared 3 packages in 139ms
# Installed 3 packages in 15ms
#  + cattrs==26.1.0
#  + coremltools==9.0
#  + pyaml==26.2.1
#
# requirements: AutoUpdate success ✅ 0.8s
# WARNING ⚠️ requirements: Restart runtime or rerun command for updates to take effect
#
# scikit-learn version 1.6.1 is not supported. Minimum required version: 0.17. Maximum required version: 1.5.1. Disabling scikit-learn conversion API.
# XGBoost version 3.2.0 has not been tested with coremltools. You may run into unexpected errors. XGBoost 1.4.2 is the most recent version that has been tested.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1771798416.330185   11400 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1771798416.337183   11400 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1771798416.356095   11400 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1771798416.356130   11400 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1771798416.356134   11400 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1771798416.356138   11400 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# TensorFlow version 2.19.0 has not been tested with coremltools. You may run into unexpected errors. TensorFlow 2.12.0 is the most recent version that has been tested.
# Torch version 2.10.0+cu128 has not been tested with coremltools. You may run into unexpected errors. Torch 2.7.0 is the most recent version that has been tested.
# WARNING:coremltools:Failed to load _MLModelProxy: No module named 'coremltools.libcoremlpython'
# WARNING:coremltools:Failed to load _MLCPUComputeDeviceProxy: No module named 'coremltools.libcoremlpython'
# WARNING:coremltools:Failed to load _MLGPUComputeDeviceProxy: No module named 'coremltools.libcoremlpython'
# WARNING:coremltools:Failed to load _MLNeuralEngineComputeDeviceProxy: No module named 'coremltools.libcoremlpython'
# WARNING:coremltools:Failed to load _MLModelProxy: No module named 'coremltools.libcoremlpython'
# WARNING:coremltools:Failed to load _MLComputePlanProxy: No module named 'coremltools.libcoremlpython'
# WARNING:coremltools:Failed to load _MLModelProxy: No module named 'coremltools.libcoremlpython'
# WARNING:coremltools:Failed to load _MLModelAssetProxy: No module named 'coremltools.libcoremlpython'
# /usr/local/lib/python3.12/dist-packages/coremltools/optimize/torch/palettization/fake_palettize.py:82: SyntaxWarning: invalid escape sequence '\_'
#   n_bits (:obj:`int`): Number of palettization bits. There would be :math:`2^{n\_bits}` unique weights in the ``LUT``.
#
# CoreML: starting export with coremltools 9.0...
# Converting PyTorch Frontend ==> MIL Ops:  70% 656/933 [00:00<00:00, 3242.36 ops/s]WARNING:coremltools:Saving value type of int64 into a builtin type of int32, might lose precision!
# Converting PyTorch Frontend ==> MIL Ops: 100% 932/933 [00:00<00:00, 3088.59 ops/s]
# Running MIL frontend_pytorch pipeline: 100% 5/5 [00:00<00:00, 74.92 passes/s]
# Running MIL default pipeline:   8% 8/95 [00:00<00:01, 77.56 passes/s]/usr/local/lib/python3.12/dist-packages/coremltools/converters/mil/mil/passes/defs/preprocess.py:273: UserWarning: Output, '1440', of the source model, has been renamed to 'var_1440' in the Core ML model.
#   warnings.warn(msg.format(var.name, new_name))
# Running MIL default pipeline:  66% 63/95 [00:01<00:01, 22.55 passes/s]/usr/local/lib/python3.12/dist-packages/coremltools/converters/mil/mil/passes/defs/optimize_repeat_ops.py:433: RuntimeWarning: overflow encountered in cast
#   max(cur_range.low, tmp_range.low), min(cur_range.high, tmp_range.high)
# Running MIL default pipeline: 100% 95/95 [00:02<00:00, 41.83 passes/s]
# Running MIL backend_mlprogram pipeline: 100% 12/12 [00:00<00:00, 73.60 passes/s]
# CoreML: export success ✅ 19.7s, saved as 'best.mlpackage' (4.8 MB)
#
# Export complete (20.4s)
# Results saved to /content/workspace
# Predict:         yolo predict task=detect model=best.mlpackage imgsz=640
# Validate:        yolo val task=detect model=best.mlpackage imgsz=640 data=converse_vans_detection.yaml
# Visualize:       https://netron.app
# 💡 Learn more at https://docs.ultralytics.com/modes/export

# %% [markdown]
# Zip the Core ML model and download it from the File browser at the left hand. You can auto label images using the Core ML model on RectLabel.

# %%
# !zip -r best.mlpackage.zip best.mlpackage
# Out:
#   adding: best.mlpackage/ (stored 0%)
#   adding: best.mlpackage/Manifest.json (deflated 59%)
#   adding: best.mlpackage/Data/ (stored 0%)
#   adding: best.mlpackage/Data/com.apple.CoreML/ (stored 0%)
#   adding: best.mlpackage/Data/com.apple.CoreML/weights/ (stored 0%)
#   adding: best.mlpackage/Data/com.apple.CoreML/weights/weight.bin (deflated 8%)
#   adding: best.mlpackage/Data/com.apple.CoreML/model.mlmodel (deflated 88%)
